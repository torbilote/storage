# %% [markdown]
# e06_debugging

# %% [markdown]
# Usually your IDLE provides the functionality for debugging your code.
# However you can debug your code without any IDE. https://realpython.com/python-debugging-pdb/

# %%
a,b = 5, 6
import pdb; pdb.set_trace()
a = 7
b = 9
# Out:
# --Return--
# None
# > c:\users\nlk04\appdata\local\temp\ipykernel_10284\1964405310.py(2)<module>()
#
# *** SyntaxError: unexpected EOF while parsing
# *** SyntaxError: unexpected EOF while parsing
# 5
# 5
# 5
# 6
# 6
# 6
# 6
# 6
# 9
#     [... skipped 1 hidden frame]
#
# > c:\users\nlk04\documents\github\adtech-ngp\.venv\lib\site-packages\ipython\core\interactiveshell.py(3511)run_code()
#    3509             finally:
#    3510                 # Reset our crash handler in place
# -> 3511                 sys.excepthook = old_excepthook
#    3512         except SystemExit as e:
#    3513             if result is not None:
#
#     [... skipped 1 hidden frame]
#
# > c:\users\nlk04\documents\github\adtech-ngp\.venv\lib\site-packages\ipython\core\interactiveshell.py(3532)run_code()
#    3530             self.showtraceback(running_compiled_code=True)
#    3531         else:
# -> 3532             outflag = False
#    3533         return outflag
#    3534
#
#     [... skipped 1 hidden frame]
# ...
